# %%
import pandas as pd

# %%
microchannel_fluidflow_df = pd.read_json('Researchpaper_list.json')

# %%
microchannel_fluidflow_df.head(10)
# Out:
#        article-type                                              title  \
# 0  Research article  Investigation of irradiation parameters on flu...
# 1  Research article  Stability and uniformity of gas–liquid two-pha...
# 2  Research article  Effect of asymmetric fluid flow distribution o...
# 3  Research article  Numerical study on heat transfer enhancement b...
# 4  Research article  Electroosmotic pressure-driven oscillatory flo...
# 5  Research article  Electroosmotic and pressure-driven slip flow o...
# 6    Review article  Fluid flow and heat transfer in microchannel h...
# 7  Research article  Heat transfer and fluid flow analysis of micro...
# 8  Research article  Thermodiffusive effect on the local Debye-leng...
# 9  Research article  Unsteady electromagnetohydrodynamic flow of co...
#
#                                              journal published-on  \
# 0                                              Optik  25 May 2022
# ...

# %%
microchannel_fluidflow_df.shape
# Out:
# (100, 8)
